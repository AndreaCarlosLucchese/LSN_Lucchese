# %% [markdown]
# # ANALISI DATI ESERCIZIO 1.1

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
plt.rcParams.update({'font.size': 14})

# %% [markdown]
# ## MEDIA
#
# Copio i file ottenuti dalle simulazioni in C++ e costruisco il grafico che mostra l'andamento della media in funzione del numero di lanci. Le barre di errore di ogni punto rapprensentano l'errore della media a blocchi. Aumentando il numero di lanci per blocco la media diventa più precisa e l'errore che facciamo nel suo calcolo diminuisce.

# %%
M=100000
N=100
L=int(M/N) 
x = np.arange(N)
x *= L # Number of throws = block * (Number of throws in each block)

# %%
plt.figure(figsize=(20,10));

sum_prog= np.loadtxt("sum_prog.txt")
err= np.loadtxt("Err.txt")
plt.hlines(0,-1,100001,color="r",label="Teo")
plt.errorbar(x,sum_prog-0.5,yerr=err,label="Sim")
plt.legend()
plt.xlabel('#throws')
plt.ylabel('<r>-1/2')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Varianza
#
# Eseguo la stessa operazione utilizzata per la media per ottenere il grafico della varianza in funzione del numero di lanci. L'andamento del grafico segue lo stesso della media.

# %%
plt.figure(figsize=(20,10));

sum_prog_var= np.loadtxt("sum_prog_var.txt")
err_var= np.loadtxt("Err_var.txt")
plt.hlines(0,-1,100001,color="r",label="Teo")
plt.errorbar(x,sum_prog_var-1/12,yerr=err_var,label="Sim")
plt.legend()
plt.xlabel('#throws')
plt.ylabel('<(r-0.5)^2>-1/12')
plt.grid(True)
plt.show()

# %% [markdown]
# ## CHI QUADRO
#
# Grafico che mostra il valore di 100 diverse calcoli del chi quadro. Si può notare come il valore si assesti intorno ad un valore di 100.

# %%
plt.figure(figsize=(20,10));

x= range(100)

plt.plot(x,chi_q)
plt.xlabel('samples')
plt.ylabel('chi_square')
plt.grid(True)
plt.show()
